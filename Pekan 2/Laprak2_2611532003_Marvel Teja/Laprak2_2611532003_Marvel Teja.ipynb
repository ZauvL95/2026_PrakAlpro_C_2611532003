# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **STRUKTUR DATA**
#
# **“Pengenalan Tipe data dan Variable”**
#
# **Disusun Oleh :**
#
# **Marvel Teja**
#
# **2611532003**
#
# **Dosen Pengampu:**
#
# **Dr. Ir WAHYUDI, ST., MT.**
#
# **Asisten Praktikum:**
#
# **Muhammad Galid Alvero**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur kehadirat Tuhan Yang Maha Esa atas segala rahmat dan karunia-Nya sehingga laporan praktikum Pemrograman Python dengan judul "PENGENALAN TIPE DATA DAN VARIABLE" ini dapat diselesaikan dengan baik dan tepat waktu.
#
# Laporan ini disusun untuk memenuhi tugas praktikum serta memperdalam pemahaman mengenai konsep dasar pemrograman Python, khususnya pada instalasi python dan visual studio code, serta integerasi dengan git menggunakan git.
#
# Penyusun menyadari bahwa laporan ini masih memiliki kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi kesempurnaan laporan ini di masa mendatang. Semoga laporan ini dapat memberikan manfaat bagi pembaca.
#
# Padang, 2026
#
# Marvel Teja

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Perkembangan teknologi yang semakin pesat membuat pemrograman menjadi salah satu kemampuan penting dalam bidang teknologi informasi. Pemrograman digunakan untuk membuat berbagai aplikasi dan menyelesaikan permasalahan secara terstruktur dan efisien. Salah satu bahasa pemrograman yang banyak digunakan untuk mempelajari dasar-dasar pemrograman adalah Python karena memiliki sintaks yang sederhana dan mudah dipahami.
#
# Dalam mempelajari Python, terdapat beberapa konsep dasar yang perlu dipahami, seperti variabel, tipe data, operator, input dan output, serta percabangan. Pemahaman terhadap konsep-konsep tersebut menjadi dasar dalam membuat suatu program. Selain itu, Python juga dapat digunakan untuk melakukan berbagai perhitungan sederhana dengan memanfaatkan tipe data numerik dan operator aritmatika.
#
# Oleh karena itu, praktikum ini dilakukan untuk memahami dan menerapkan konsep dasar pemrograman Python melalui beberapa program sederhana. Program yang dibuat mencakup penggunaan tipe data integer, float, complex, string, dan boolean, penggunaan input dan output, percabangan, serta penerapan operasi aritmatika untuk menghitung luas bangun datar. Dengan praktikum ini, diharapkan mahasiswa dapat memahami dasar-dasar Python dan mampu menerapkannya dalam pembuatan program sederhana.
#
#
# ## 1.2 Tujuan
# 1. Memahami konsep dasar pemrograman menggunakan bahasa Python.
# 2. Mengetahui dan memahami berbagai tipe data yang digunakan dalam Python.
# 3. Mempelajari penggunaan variabel, operator, input, dan output dalam program Python.
# 4. Memahami penggunaan percabangan if dan operator logika dalam membuat suatu kondisi.
# 5. Mampu membuat program sederhana untuk melakukan perhitungan menggunakan Python.
#
# ## 1.3 Manfaat
# 1. Menambah pemahaman mengenai dasar-dasar pemrograman Python.
# 2. Melatih kemampuan dalam membuat dan menjalankan program sederhana.
# 3. Meningkatkan kemampuan dalam menggunakan tipe data dan variabel sesuai kebutuhan.
# 4. Melatih kemampuan berpikir logis dan sistematis dalam menyelesaikan permasalahan menggunakan program.
# 5. Menjadi dasar untuk mempelajari konsep pemrograman Python yang lebih lanjut.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
#
# Python merupakan bahasa pemrograman tingkat tinggi yang memiliki sintaks sederhana dan mudah dipahami. Python dapat digunakan untuk membuat berbagai jenis program, mulai dari program sederhana hingga aplikasi yang kompleks. Dalam pemrograman Python terdapat beberapa konsep dasar yang perlu dipahami, seperti variabel, tipe data, operator, input, output, dan percabangan.
#
# 1. Variabel
# Variabel merupakan tempat untuk menyimpan suatu data dalam program. Dalam Python, variabel dapat dibuat dengan memberikan nilai secara langsung tanpa harus menentukan tipe datanya terlebih dahulu. Contohnya adalah nilai = 85.
#
# 2. Tipe Data
# Tipe data digunakan untuk menentukan jenis nilai yang disimpan dalam sebuah variabel. Beberapa tipe data dasar dalam Python adalah int untuk bilangan bulat, float untuk bilangan desimal, complex untuk bilangan kompleks, str untuk teks, dan bool untuk nilai benar atau salah (True dan False).
#
# 3. Input dan Output
# Input digunakan untuk menerima data dari pengguna, salah satunya menggunakan fungsi input(). Sementara itu, output digunakan untuk menampilkan informasi atau hasil program menggunakan fungsi print(). Data yang diperoleh dari input() secara default berupa string sehingga perlu dikonversi menggunakan fungsi seperti int() atau float() jika akan digunakan dalam perhitungan.
#
# 4. Operator
# Operator digunakan untuk melakukan operasi terhadap data. Operator aritmatika seperti +, -, *, dan / digunakan untuk melakukan perhitungan. Selain itu, terdapat operator perbandingan seperti >= yang menghasilkan nilai boolean berdasarkan hasil perbandingan.
#
# 5. Percabangan
# Percabangan digunakan untuk menjalankan perintah berdasarkan kondisi tertentu. Dalam Python, percabangan dapat menggunakan if. Operator logika seperti and dapat digunakan untuk menggabungkan beberapa kondisi dalam suatu percabangan.
#
# 6. Konstanta
# Konstanta merupakan nilai yang digunakan sebagai nilai tetap dalam program. Pada Python, konstanta dapat ditandai menggunakan Final dari modul typing untuk menunjukkan bahwa nilai tersebut tidak dimaksudkan untuk diubah. Salah satu contohnya adalah konstanta PI yang digunakan dalam perhitungan luas lingkaran.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "Numerik_2611532003.py"

# %%
# Buat file  dengan nama Numerik_NIM.py
# nama variable ditambah 4 digit terakhir NIM contoh: a_5500
# Create a variable with numeric type value.
a_2003 = 100
print("The type of variable having value", a_2003, " is", type(a_2003))

# Create a variable with float value
b_2003 = 10.2345
print("The type of variable having value", b_2003, " is", type(b_2003))

# Create a variable with complex value
c_2003 = 100 + 3j
print("The type of variable having value", c_2003, " is", type(c_2003))
# Out:
# The type of variable having value 100  is <class 'int'>
# The type of variable having value 10.2345  is <class 'float'>
# The type of variable having value (100+3j)  is <class 'complex'>

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama kode ini berfungsi untuk membuat variabel a_2003 dengan nilai 100 dan menampilkan tipe data dari variabel tersebut. Nilai 100 termasuk tipe data integer (int).
# 2. Bagian kedua berfungsi untuk membuat variabel b_2003 dengan nilai 10.2345 dan menampilkan tipe data dari variabel tersebut. Nilai tersebut termasuk tipe data float karena memiliki angka desimal.
# 3. Bagian ketiga berfungsi untuk membuat variabel c_2003 dengan nilai 100 + 3j dan menampilkan tipe data dari variabel tersebut. Nilai tersebut termasuk tipe data complex karena memiliki bagian bilangan imajiner yang ditandai dengan j.

# %% [markdown]
# ### 2.2.2 Program "String_2611532003.py"

# %%
# Buat file dengan nama string_NIM.py
# nama variable ditambah 4 digit nim terakhir contoh: nama_1234
# ganti programnya dan data masing2
nama_2003 = "Marvel Teja"
jenis_kelamin_2003 = 'L'
alamat_2003 = """
    Jl. Kotomerapak no 16
    Kec. Padang barat
    Kota padang
"""
agama_2003 = 'Buddha'
print("Nama saya adalah: ", nama_2003)
print("Jenis kelamin saya adalah: ", jenis_kelamin_2003)
print("Alamat saya adalah: ", alamat_2003)
print("Agama saya adalah: ", agama_2003)
# Out:
# Nama saya adalah:  Marvel Teja
# Jenis kelamin saya adalah:  L
# Alamat saya adalah:
#     Jl. Kotomerapak no 16
#     Kec. Padang barat
#     Kota padang
#
# Agama saya adalah:  Buddha

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama kode ini berfungsi untuk membuat variabel nama_2003 yang menyimpan data berupa teks (string), yaitu nama "Marvel Teja".
# 2. Bagian kedua berfungsi untuk membuat variabel jenis_kelamin_2003 yang menyimpan karakter "L", yang menunjukkan jenis kelamin laki-laki.
# 3. Bagian ketiga berfungsi untuk membuat variabel alamat_2003 yang menyimpan data teks dalam beberapa baris (multiline string) menggunakan tanda petik tiga ("""). Data tersebut berisi alamat.
# 4. Bagian keempat berfungsi untuk membuat variabel agama_2003 yang menyimpan data berupa teks, yaitu "Buddha".
# 5. Bagian kelima berfungsi untuk menampilkan isi dari variabel nama_2003, jenis_kelamin_2003, alamat_2003, dan agama_2003 menggunakan fungsi print().

# %% [markdown]
# ### 2.2.3 Program "Boolean_2611532003.py"

# %%
# Buat file dengan nama Boolean_NIM.py
# Nama variable dtambah 4 digit terakhir contoh: nilai_1234
# Deklarasi variable dengan tipe data boolean
is_lulus_2003 = True
is_cumlaude_2003 = True

# Mengisi Boolean
nilai_2003 = 85
batas_lulus_2003 = 75

# Menentukan nilai Boolean dari kondisi
status_kelulusan_2003 = nilai_2003 >= batas_lulus_2003 # Hasilnya akan True

print("=== Check Kelulusan ===")
print("Nilai:", nilai_2003)
print("Apakah Lulus?:", status_kelulusan_2003)
if is_lulus_2003 and is_cumlaude_2003:
    print("Selamat, Anda lulus dengan predikat Cum Laude")
# Out:
# === Check Kelulusan ===
# Nilai: 85
# Apakah Lulus?: True
# Selamat, Anda lulus dengan predikat Cum Laude

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama kode ini berfungsi untuk membuat variabel is_lulus_2003 dan is_cumlaude_2003 dengan nilai True yang menunjukkan kondisi benar.
# 2. Bagian kedua berfungsi untuk membuat variabel nilai_2003 dengan nilai 85 dan batas_lulus_2003 dengan nilai 75 sebagai nilai minimum kelulusan.
# 3. Bagian ketiga berfungsi untuk membandingkan nilai_2003 dengan batas_lulus_2003. Karena 85 lebih besar atau sama dengan 75, maka status_kelulusan_2003 menghasilkan nilai True.
# 4. Bagian keempat berfungsi untuk menampilkan informasi nilai dan status kelulusan menggunakan fungsi print().
# 5. Bagian kelima menggunakan kondisi if dan operator and untuk memeriksa apakah mahasiswa lulus dan mendapatkan predikat Cum Laude. Karena kedua variabel bernilai True, program menampilkan pesan "Selamat, Anda lulus dengan predikat Cum Laude".

# %% [markdown]
# ### 2.2.4 Program "Input_2611532003.py"

# %%
# Buat file dengan nama Input_NIM.py
# Buat program untuk menghitung luas persegi panjang
# Nama variable ditambah 4 digit nim terakhir contoh: panjang_1234
# Program ini menggunakan fungsi input() untuk meminta pengguna
# memasukkan nilai panjang dan lebar persegi panjang.
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
panjang_2003 = input('Masukkan nilai panjang: ')
lebar_2003 = input('Masukkan nilai lebar: ')
luas_2003 = int(panjang_2003) * int(lebar_2003)
print("Luas =", luas_2003)
# Out:
# Luas = 10000

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama berfungsi untuk meminta pengguna memasukkan nilai panjang menggunakan fungsi input(), kemudian menyimpannya ke dalam variabel panjang_2003.
# 2. Bagian kedua berfungsi untuk meminta pengguna memasukkan nilai lebar menggunakan fungsi input(), kemudian menyimpannya ke dalam variabel lebar_2003.
# 3. Bagian ketiga berfungsi untuk menghitung luas persegi panjang dengan mengalikan nilai panjang dan lebar. Fungsi int() digunakan untuk mengubah input yang awalnya berupa teks menjadi bilangan bulat.
# 4. Bagian keempat berfungsi untuk menampilkan hasil perhitungan luas menggunakan fungsi print().

# %% [markdown]
# ### 2.2.5 Program "Konstanta_2611532003.py"

# %%
# Buat nama dengan nama Konstanta_NIM.py
# Program ini menggunakan konstanta untuk menghitung luas lingkaran
# nama variable ditambah 4 digit nim terakhir contoh: jari_1234

from typing import Final
PI: Final = 3.14
print("pi: %f" % (PI))
jari_2003 = float(input('Masukkan nilai jari jari: '))
luas_2003 = PI * jari_2003 *jari_2003
print("Luas lingkaran dengan jari jari %.2f adalah %.2f" % (jari_2003,luas_2003))
# Out:
# pi: 3.140000
# Luas lingkaran dengan jari jari 7.00 adalah 153.86

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama berfungsi untuk mengimpor Final dari modul typing dan menetapkan nilai konstanta PI sebesar 3.14.
# 2. Bagian kedua berfungsi untuk menampilkan nilai PI dengan format bilangan desimal.
# 3. Bagian ketiga berfungsi untuk meminta pengguna memasukkan nilai jari-jari lingkaran, kemudian mengubah input tersebut menjadi tipe data float dan menyimpannya dalam variabel jari_2003.
# 4. Bagian keempat berfungsi untuk menghitung luas lingkaran dengan menggunakan nilai PI dan jari-jari yang telah dimasukkan.
# 5. Bagian kelima berfungsi untuk menampilkan hasil perhitungan luas lingkaran dengan nilai jari-jari dan luas yang ditampilkan hingga dua angka di belakang koma.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa Python memiliki berbagai tipe data dan struktur dasar yang dapat digunakan untuk membuat program sederhana. Tipe data yang dipelajari meliputi integer, float, complex, string, dan boolean. Selain itu, praktikum juga memahami penggunaan variabel, operator perbandingan dan logika, percabangan if, serta fungsi input() dan print() untuk menerima dan menampilkan data.
#
# Melalui program yang dibuat, dapat diketahui bahwa data yang dimasukkan oleh pengguna melalui input() perlu dikonversi ke tipe data yang sesuai sebelum digunakan dalam perhitungan. Praktikum juga menunjukkan penerapan Python dalam melakukan perhitungan sederhana, seperti menghitung luas persegi panjang dan luas lingkaran. Dengan demikian, praktikum ini membantu memahami konsep dasar pemrograman Python sebagai dasar untuk membuat program yang lebih kompleks.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Python Software Foundation. (2023). Python 3.11.9 documentation.
#
# [2] Microsoft. (2024). Visual Studio Code Documentation. Diakses dari https://code.visualstudio.com/docs
#
# [3] GitHub, Inc. (2024). GitHub Docs. Diakses dari https://docs.github.com
