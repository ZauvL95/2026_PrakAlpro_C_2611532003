# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **STRUKTUR DATA**
#
# **“INSTALASI VISUAL STUDIO CODE, PYTHON, DAN INTEGRASI GITHUB MENGGUNAKAN GIT”**
#
# **Disusun Oleh :**
#
# **Marvel Teja**
#
# **2611532003**
#
# **Dosen Pengampu:**
#
# **Dr. Ir WAHYUDI, ST., MT.**
#
# **Asisten Praktikum:**
#
# **Muhammad Galid Alvero**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur kehadirat Tuhan Yang Maha Esa atas segala rahmat dan karunia-Nya sehingga laporan praktikum Pemrograman Python dengan judul "INSTALASI VISUAL STUDIO CODE, PYTHON, DAN INTEGERASI GITHUB MENGGUNAKAN GIT" ini dapat diselesaikan dengan baik dan tepat waktu.
#
# Laporan ini disusun untuk memenuhi tugas praktikum serta memperdalam pemahaman mengenai konsep dasar pemrograman Python, khususnya pada instalasi python dan visual studio code, serta integerasi dengan git menggunakan git.
#
# Penyusun menyadari bahwa laporan ini masih memiliki kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi kesempurnaan laporan ini di masa mendatang. Semoga laporan ini dapat memberikan manfaat bagi pembaca.
#
# Padang, 2026
#
# Marvel Teja

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Dalam proses pembelajaran dan pengembangan perangkat lunak, diperlukan beberapa perangkat lunak pendukung untuk menulis, menjalankan, dan mengelola kode program. Salah satu perangkat lunak yang banyak digunakan adalah Visual Studio Code (VS Code). Visual Studio Code (VS Code) merupakan code editor yang dapat digunakan untuk berbagai bahasa pemrograman, salah satu contohnya adalah Bahasa Python.
#
# Python merupakan bahasa pemrograman yang banyak digunakan karena memiliki syntax yang sederhana dab dapat digunakan untuk berbagai keperluan, dan pengembangan perangkat lunak.
#
# Selain perangkay untuk menulis dan menjalankan program, diperlukan juga sistem untuk mengelola code. Git merupakan salah satu sistem version control yang digunakan untuk mencatat perubahan pada suatu proyek. GitHub merupakan layanan yang dapat digunakan untuk menyimpan repository Git secara daring (online) sehingga code dapat diakses, dikelola, dan dibagikan.
#
# Pada pratikum ini dilakukan proses instalasi Visual Studio Code (VS Code) dan Bahasa Pemrograman Python, kemudian melakukan konfigurasi agar Python dapat digunakan melalui Visual Studio Code (VS Code). Selain itu, pratikum juga mempelajari penggunaan Git serta cara menghubungkan Visual Studio Code dengan GitHub untuk mengelola dan mengunggah proyek.
#
# ## 1.2 Tujuan
# 1. Mengetahui cara melakukan instalasi Visual Studio Code.
# 2. Mengetahui cara melakukan instalasi Bahasa Pemrograman Python.
# 3. Mengetahui cara menghubungkan Visual Studio Code dengan GitHub menggunakan Git.
#
# ## 1.3 Manfaat
# 1. Mahasiswa dapat memahami dan mampu melakukan instalasi Visual Studio Code dan Python.
# 2. Mahasiswa dapat memahami penggunaan GitHub dan Git, serta mampu menghubungkan proyek pada VS Code dengan respository GitHub.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
#
# 1. Bahasa Pemrograman Python
# Python merupakan bahasa pemrograman tingkat tinggi yang bersifat interpreted dan berfokus pada keterbacaan kode. Bahasa ini cocok untuk pemula karena struktur sintaksnya intuitif dan tidak memerlukan deklarasi variabel yang rumit.
# 2. Github
# Github adalah platform berbasis cloud dan layanan hosting web untuk menyimpan, mengelola, serta berkolaborasi dalam mengembangkan kode pemograman menggunakan sistem kontrol versi.
# 3. Git
# Git adalah sistem kontrol versi terdistribusi yang digunakan untuk mencatat perubahan file atau kode program pada proyek pengembangan perangkat lunak.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "program1_2611532003.py"

# %%
#Program Pertama
"""
Komentar
dua baris atau lebih
pertemuan 1 pratikum alpro
"""

print("Hello World")
print()
print("Departemen Informatika")
print("Universitas Andalas")
print("/ \\ // \\\\ /// \\\\\\")
print("Program ini" + "dibuat oleh a\\n" 
+ "Marvel Teja 2611532003")
# Out:
# Hello World
#
# Departemen Informatika
# Universitas Andalas
# / \ // \\ /// \\\
# Program ini dibuat oleh a\nMarvel Teja 2611532003

# %% [markdown]
# **Penjelasan :**
# 1. Tanda # berfungsi untuk memberikan komentar 1 baris.
# 2. Tanda """ berfungsi untuk memberikan komentar lebih dari 1 baris.
# 3. Syntax print() berfungsi untuk mencetak data.

# %% [markdown]
# ### 2.2.2 Program Driver "NamaDriver_NIM"

# %%
git init
git add .
git commit -m "Initial commit"
git branch -M main
git remote add origin https://github.com/username/nama-repository.git
git push -u origin main

# %% [markdown]
# **Penjelasan :**
# 1. git init digunakan untuk membuat repository Git pada folder proyek.
# 2. git add . digunakan untuk menambahkan seluruh perubahan ke staging area.
# 3. git commit digunakan untuk menyimpan perubahan dengan sebuah pesan.
# 4. git branch -M main digunakan untuk menentukan branch utama dengan nama main.
# 5. git remote add origin digunakan untuk menghubungkan repository lokal dengan repository GitHub.
# 6. git push digunakan untuk mengunggah kode dari komputer ke GitHub.

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :**
#
# <div align="center">
# <img src="images/soal_tugas.png" width="500"><br>
# <em>Gambar 2.2 : Soal Tugas Praktikum</em>
# </div>

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "Tugas1_2611532003.py"

# %%
while True:
    angka_1 = int(input("Masukkan angka pertama: "))
    angka_2 = int(input("Masukkan angka kedua: "))
    operasi = input("Masukkan operasi (+, -, *, /): ")

    def tambah(a, b):
        hasil = a + b
        return hasil

    def kurang(a, b):
        hasil = a - b
        return hasil

    def kali(a, b):
        hasil = a * b
        return hasil

    def bagi(a, b):
        hasil = a / b
        return hasil

    if operasi == "+":
        print("Hasil penjumlahan adalah:", tambah(angka_1, angka_2))
    elif operasi == "-":
        print("Hasil pengurangan adalah:", kurang(angka_1, angka_2))
    elif operasi == "*":
        print("Hasil perkalian adalah:", kali(angka_1, angka_2))
    elif operasi == "/":
        print("Hasil pembagian adalah:", bagi(angka_1, angka_2))
    else:
        print("Operasi tidak valid. Silakan masukkan operasi yang benar (+, -, *, /).")

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/output_tugas.png" width="400"><br>
# <em>Gambar 2.3 : Output Tugas Praktikum</em>
# </div>
#
# **Penjelasan :**
# Program ini digunakan untuk menghitung 2 buah angka. Awalnya program akan memintak untuk memasukkan angka pertama, kedua, lalu operasinya. Saat ketiga input tersebut sudah didapat maka program akan mengecek operasi mana yang digunakan lalu di masukkan ke dalam function yang tersedia.
#
# 1. While digunakan agar program bisa berulang.
# 2. Variable digunakan agar data yang diinputkkan dapat disimpan.
# 3. def() digunakan untuk mendefenisikan fungsi.
# 4. if, elif, dan else digunakan untuk menjalankan program pada kondisi tertentu.
# 5. print() digunakan untuk mencetak hasil.
# 6. input() digunakan untuk memintak pengguna memasukkan data.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa Python, Visual Studio Code, Git, dan GitHub merupakan tools yang penting dalam proses pengembangan perangkat lunak. Melalui praktikum ini, mahasiswa mempelajari cara menggunakan Python untuk membuat dan menjalankan program menggunakan Visual Studio Code.
#
# Selain itu, praktikum ini juga memberikan pemahaman dasar mengenai penggunaan Git dan GitHub untuk menyimpan, mengelola, dan mengontrol versi kode secara daring. Dengan menggunakan tools tersebut, proses pembuatan dan pengelolaan program dapat dilakukan dengan lebih teratur dan memudahkan dalam pengembangan program secara bersama-sama.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Penulis, "Judul Referensi," Nama Situs/Jurnal, [Tahun]. [Online]. Tersedia: https://... [Diakses tanggal].
#
# [2] Penulis, "Judul Buku/Diktat," [Tahun], Hal. ...
